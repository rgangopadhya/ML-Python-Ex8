# %%
import numpy as npimport matplotlib.pyplot as pyplotfrom recommend import *import syssys.path.append(r'/home/raja/Documents/MachineLearning/ex7/ex7/Python')sys.path.append(r'/home/raja/Documents/MachineLearning/ex8')from kmeans import import_mlab%pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
pd = import_mlab('ex8_movies.mat')

# %%
#average for movie 1np.mean(pd['Y'][0, pd['R'][0, :] == 1])
# Out:
# 3.8783185840707963

# %%
pyplot.imshow(pd['Y'])pyplot.ylabel('Movies')pyplot.xlabel('Users')
